# %%
import pandas as pd

eluniversal = pd.read_csv('clean_eluniversal_2020_04_12_articles.csv')

# %%
eluniversal.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count        5.000000       5.000000
# mean         5.600000     393.800000
# std          0.547723     457.025929
# min          5.000000      49.000000
# 25%          5.000000     205.000000
# 50%          6.000000     210.000000
# 75%          6.000000     311.000000
# max          6.000000    1194.000000

# %%
eluniversal.loc[eluniversal['n_tokens_title'] == 6]
# Out:
#                                 uid  \
# 0  912e17d4a9a1d4c9beefb95604229f7e
# 2  cb64c5b14326ddbcffa1c29c34b44969
# 4  7ef9941ec843cef988ef6729a3dc7047
#
#                                                 body  \
# 0    Nairobi.- Un bebé cría de una cebra y un bur...
# 2    La actriz Eiza González está pasando la cuar...
# 4    El Sábado de Gloria de este año pasará a la ...
#
#                                                title  \
# 0  Nace en Kenia "zonkey", una cría de cebra y burro
# 2  eiza gonzalez presume silueta en bikini durant...
# 4  Vive la capital un Sábado de Gloria sin tráfic...
#
#                                                  url newspaper_uid  \
# 0  http://www.eluniversal.com.mx/mundo/nace-en-ke...   eluniversal
# 2  https://www.viveusa.mx/showbiz/eiza-gonzalez-p...   eluniversal
# 4  http://www.eluniversal.com.mx/nacion/vive-la-c...   eluniversal
#
#                      host  n_tokens_title  n_tokens_body
# ...

# %%
# %matplotlib inline

# %%
eluniversal['n_tokens_body'].plot(style='r.')

# %%
eluniversal.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021D5EEF6190>,
# ...
#       dtype=object)

# %%
eluniversal['n_tokens_body'].agg(['min', 'max', 'mean'])
# Out:
# min       49.0
# max     1194.0
# mean     393.8
# Name: n_tokens_body, dtype: float64
